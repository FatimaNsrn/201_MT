# %% [markdown]
# # Task
# Evaluate the Llama model's translation performance on 100 sampled rows from the `shenasa/English-Persian-Parallel-Dataset` by calculating and presenting BLEU, CHRF++, and BERTScore metrics.

# %% [markdown]
# ## Load Model, Tokenizer, and Dataset
#
# ### Subtask:
# Load the Llama model and tokenizer using `AutoModelForCausalLM` and `AutoTokenizer` from `transformers` as specified. Then, load the `shenasa/English-Persian-Parallel-Dataset` using `load_dataset` from `datasets`.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset

# Choose a specific Llama model for translation
model = AutoModelForCausalLM.from_pretrained("Sheikhaei/llama-3.2-1b-en-fa-translator", torch_dtype="auto", device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("Sheikhaei/llama-3.2-1b-en-fa-translator")


# Load the dataset
dataset = load_dataset('shenasa/English-Persian-Parallel-Dataset')

# Print the loaded dataset to inspect its structure
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['flash fire .', 'فلاش آتش .'],
#         num_rows: 3960172
#     })
# })

# %% [markdown]
# ## Inspect Dataset and Prepare Sample
#
# ### Subtask:
# Inspect the structure of the loaded dataset to identify the appropriate source and target language columns. Then, sample 100 rows from the dataset for evaluation, making sure to extract the source and target texts.

# %%
import random

source_column = 'flash fire .'
target_column = 'فلاش آتش .'

# Sample 100 random rows from the 'train' split
sampled_indices = random.sample(range(len(dataset['train'])), 100)
sampled_dataset = dataset['train'].select(sampled_indices)

# Extract source and target texts
source_texts = sampled_dataset[source_column]
target_texts = sampled_dataset[target_column]

print(f"Sampled {len(source_texts)} source texts and {len(target_texts)} target texts.")
print("First 3 source texts:", source_texts[:3])
print("First 3 target texts:", target_texts[:3])
# Out:
# Sampled 100 source texts and 100 target texts.
# First 3 source texts: ['for Janni was physically precocious and had quickly taken the leadership of the pair.', 'Whatever the cause, you should know that God hates divorce and says:', 'LanSAages: Kazakh, Russian']
# First 3 target texts: ['زیرا جانی از نظر بدنی زودرس بود و به سرعت رهبری این زوج را به دست گرفته بود .', 'علتش هرچه که باشد باید بدانید که خداوند از طلاق بیزار است و می فرماید :', 'LanSAages : قزاق ، روسی']

# %%
import torch
import random

# Initialize a list to store generated Persian texts
generated_persian_texts = []

# Generate 10 random indices from the 100 available samples
# source_texts and target_texts already contain 100 random samples from the full dataset.
random_100_indices = random.sample(range(len(source_texts)), 100)

# Iterate through the 100 random items from the source_texts and target_texts lists
for i, idx in enumerate(random_100_indices):
    english_text = source_texts[idx]
    actual_persian_text = target_texts[idx]

    print(f"\n--- Sample {i+1} ---")

    # a. Construct the prompt string
    prompt = f"### English:\n{english_text}\n### Persian:\n"

    # b. Tokenize the prompt
    inputs = tokenizer(prompt, return_tensors='pt').to(model.device)

    # c. Generate the translation
    # Ensure to only generate new tokens, not re-generate the prompt
    # max_new_tokens is crucial here to prevent infinite generation
    outputs = model.generate(
        **inputs,
        max_new_tokens=100,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        num_return_sequences=1,
        pad_token_id=tokenizer.eos_token_id # Set pad_token_id to eos_token_id
    )

    # d. Decode the generated tokens back to a string
    # Decode the *new* tokens, not the input prompt
    translated_text = tokenizer.decode(outputs[0][len(inputs['input_ids'][0]):], skip_special_tokens=True)

    # e. Extract only the Persian translation from translated_text
    # The model might sometimes generate text that includes the prompt structure itself if not properly constrained.
    # We are looking for the content that *should* be the Persian translation.
    predicted_persian_text = translated_text.strip()

    # f. Append the predicted_persian_text to the generated_persian_texts list
    generated_persian_texts.append(predicted_persian_text)

    # g. Print the original English text, the predicted_persian_text, and the actual Persian text
    print(f"Original English: {english_text}")
    print(f"Predicted Persian: {predicted_persian_text}")
    print(f"Actual Persian: {actual_persian_text}")

print(f"\nGenerated {len(generated_persian_texts)} Persian translations.")
# Out:
# --- Sample 1 ---
# Original English: Compare various nutrients in fruits, vegetables, cereals and legumes that are rich in Water.
# Predicted Persian: تفاوت مواد مغذی مختلف در میوه‌ها، سبزیجات، گلاتان و لجن‌داران را با توجه به غلظت آب بررسی کنید.
# Actual Persian: مواد مغذی مختلف موجود در میوه ها ، سبزیجات ، غلات و حبوبات را که سرشار از آب هستند ، مقایسه کنید .
#
# --- Sample 2 ---
# Original English: The main changes are:
# Predicted Persian: تغییرات اصلی:
# Actual Persian: تغییرات اصلی عبارتند از :
#
# --- Sample 3 ---
# Original English: Basics of Ecology (for students of non-biological specialties of the University).
# Predicted Persian: معلولیت‌ها در اکولوژی (برای دانشجویان رشته‌های غیرزیست‌شناسی دانشگاهی).
# Actual Persian: مبانی بوم شناسی ( برای دانشجویان رشته های غیر زیستی دانشگاه ).
#
# --- Sample 4 ---
# Original English: A 17th century Chateau of of about 1000 m2 habittable plus numerous annexes in an exceptional and tranquil setting of 150 hectares hence 40 hectaures of vineyards all A.O.C..Beautiful views of St. Victoire. Only 20 minutes to high speed (TGV) station and 30 minutes from the international airport of Marseille - Provence. Full documentation on request.
# Predicted Persian: یک کاخ قرن هجدهم با حدود ۱۰۰۰ متر مربع مساحتی قابل مسکونی و در یک موقعیت استثنایی و آرام با مساحت ۱۵۰ هکتار و با تعداد زیادی بنای اضافی، شامل ۴۰ هکتار از تاکستان - دارای آکلاسیفیکاسیون - در محوطه. منظره‌های زیبایی از سنت ویکتور. تنها ۲۰ دقیقه به ایستگاه سرعت بالا (TGV) و ۳۰
# Actual Persian: قصر قرن هفدهمی با مساحتی حدود 1000 مترمربع قابل سکونت به علاوه ضمیمه های متعدد در محیطی استثنایی و آرام به وسعت 150 هکتار ، از این رو 40 هکتار باغ انگور که تماما A . O . C .. چشم اندازهای زیبا از سنت ویکتوریا . فقط 20 دقیقه تا ایستگاه پرسرعت ( TGV ) و 30 دقیقه تا فرودگاه بین المللی مارسی - پروونس . مستندات کامل در صورت درخواست
#
# --- Sample 5 ---
# Original English: My heart thudded in my chest.
# Predicted Persian: قلبم در سینه‌ام می‌کوبید.
# Actual Persian: قلبم در سینه ام کوبید .
#
# --- Sample 6 ---
# Original English: There are about 10 reasons that make Titan Poker number one.
# Predicted Persian: تقریباً ده دلیل وجود دارد که Titan Poker را به عنوان شماره یک انتخاب کرده‌اند.
# Actual Persian: حدود 10 دلیل وجود دارد که پوکر تایتان را شماره یک می کند .
#
# --- Sample 7 ---
# Original English: i like that one in the front .
# Predicted Persian: اون یکی رو جلوی توش دوست دارم.
# Actual Persian: من اون جلو رو دوست دارم
#
# --- Sample 8 ---
# Original English: It reveals his ego as the illusion which envelops his consciousness and his Overself as the reality behind his consciousness.
# Predicted Persian: این، خودشیفتگی او را به عنوان توهمی که آگاهی و خودِ فراتر از آگاهی‌اش را در بر می‌گیرد، و واقعیت پشت آگاهی‌اش را به عنوان واقعیتِ پشتِ آگاهی نشان می‌دهد.
# Actual Persian: منیت او را به عنوان توهمی که آگاهی او را در بر می گیرد و خود او را به عنوان واقعیتی که در پشت آگاهی او قرار دارد آشکار می کند .
#
# --- Sample 9 ---
# Original English: dont worry . ill clean it up .
# Predicted Persian: نگران نباش، من تمیزش می‌کنم.
# Actual Persian: نگران نباش بد پاک کردنش .
#
# --- Sample 10 ---
# Original English: N = 4
# Predicted Persian: N = 4
# Actual Persian: N = 4
#
# --- Sample 11 ---
# Original English: Transmitted: 12/9/2017 3:51:59 AM
# Predicted Persian: ارسال شد: ۱۲/۹/۲۰۱۷ ۰۳:۵۱:۹۹ صبح
# Actual Persian: ارسال شده : 1396 / 9 / 12 ساعت 3 : 51 : 59 ق . ظ
#
# --- Sample 12 ---
# Original English: i will protect you .
# Predicted Persian: من ازت محافظت می‌کنم.
# Actual Persian: من از تو محافظت خواهم کرد .
#
# --- Sample 13 ---
# Original English: Product description.
# Predicted Persian: کد محصول: 17-0000-001-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-
# Actual Persian: توضیحات محصول .
#
# --- Sample 14 ---
# Original English: 2) 0,0048% of themarket value of the money and securities managed by the investment institution as on the last banking day of the quarter preceding payment of the contribution.
# Predicted Persian: ۲) ۴۸ میلی‌تومارتریتیمال ارزش پول و دارایی‌های مالی مدیریت‌شده توسط این موسسه سرمایه‌گذاری به عنوان آخرین روز بانکداری ماه قبل از پرداخت کمک مالی.
# Actual Persian: 2 ) 0 ، 0048 % ارزش بازار پول و اوراق بهادار تحت مدیریت موسسه سرمایه گذاری در آخرین روز بانکی سه ماهه قبل از پرداخت سهم .
#
# --- Sample 15 ---
# Original English: Don't shoot
# Predicted Persian: تیر نزن
# Actual Persian: شلیک نکن
#
# --- Sample 16 ---
# Original English: "JSC NC ""KazMunayGas"" USD 2 000"
# Predicted Persian: "JSC NC "KazMunayGas" USD 2 000"
# Actual Persian: " JSC NC "" KazMunayGas "" USD 2000 "
#
# --- Sample 17 ---
# Original English: then we need to do this now .
# Predicted Persian: پس باید الان این کار را انجام دهیم.
# Actual Persian: پس ما باید این کار را در حال حاضر انجام دهیم .
#
# --- Sample 18 ---
# Original English: Address: 4, Al-Kawakibi, 12 Taha-Hussein, P.O. Box: 4670, Aleppo, Syria
# Predicted Persian: آدرس: ۴، کاواکوبی، ۱۲ تاها الحسینی، پوستر: ۴۷۶۰، الرفاع، سوریه
# Actual Persian: آدرس : الکواکبی ، 12 طه حسین ، پ . جعبه : 4670 ، حلب ، سوریه
#
# --- Sample 19 ---
# Original English: Despite the writing on the wall about the company's impending layoffs, everyone continued to ignore the elephant in the room and pretended that everything was business as usual, leaving those who were in the know feeling like they were caught between a rock and a hard place.
# Predicted Persian: با وجود نوشته‌هایی که درباره‌ی اخراج پیش‌بینی‌شده‌ی کارکنان در دیوارها دیده می‌شد، همه به همین ترتیب از موضوع در اتاق غبارپردازی نادیده می‌گرفتند و وانمود می‌کردند همه چیز طبق معمول پیش می‌رود، و کسانی که از این موضوع آگاه بودند، احساس می‌کردند بین سنگ و خش و گیر افتاده‌اند.
# Actual Persian: با وجود نشانه های روشن درباره اخراج های قریب الوقوع در شرکت ، همه به نادیده گرفتن مشکل اصلی پرداختند و وانمود کردند که همه چیز طبق روال عادی پیش می رود . این وضعیت باعث شد کسانی که از حقیقت باخبر بودند ، خود را
#
# --- Sample 20 ---
# Original English: youre so deeply sorry that he forgives you .
# Predicted Persian: بابت این کارش خیلی متاسفم که تو رو می‌بخشد.
# Actual Persian: شما عمیقا متاسفید که او شما را می بخشد .
#
# --- Sample 21 ---
# Original English: Other games like Banana Rama
# Predicted Persian: بازی‌های مشابه بَنانا راما
# Actual Persian: بازی های دیگری مانند Banana Rama
#
# --- Sample 22 ---
# Original English: "]]> 2003-07-30T09:30:54+02:00 2003-07-30T09:30:54+02:00 http://www.hiphop.com.cy/forums/viewtopic.php?t=138&p=1024#p1024 <![CDATA[Mcs tragoudane stixous ""megalwn""??]]>"
# Predicted Persian: "2003-07-30T09:30:54+02:00 2003-07-30T09:30:54+02:00 http://www.hiphop.com.cy/forums/viewtopic.php?t=138&p=1024#p1024" "مِگالون"؟"
# Actual Persian: "]]> 2003 - 07 - 30T09 : 30 : 54 + 02 : 00 2003 - 07 - 30T09 : 30 : 54 + 02 : 00 http :// www . hiphop . com . cy / forums / viewtopic . php ? t = 138 & p = 1024 # p1024 <![ CDATA [ Mcs tragoudane stixous "" megalwn ""??]]>"
#
# --- Sample 23 ---
# Original English: Adra 950816 *** Phone
# Predicted Persian: آدرا 950816 *** تلفن
# Actual Persian: آدرا 950816 *** تلفن
#
# --- Sample 24 ---
# Original English: 'It is a shame, though '
# Predicted Persian: متاسف‌کننده است، اما...
# Actual Persian: " اگرچه شرم آور است "
#
# --- Sample 25 ---
# Original English: Category: Hi-tech
# Predicted Persian: کатегорی: هِی‌تِک
# Actual Persian: دسته : فناوری پیشرفته
#
# --- Sample 26 ---
# Original English: But I hope not.
# Predicted Persian: اما امیدوارم نه.
# Actual Persian: اما امیدوارم نه .
#
# --- Sample 27 ---
# Original English: He has still to take another two or three steps away from the Rights towards the Central Committee fully to arrive at the position of the present leadership of the German Communist Party. I am far from regarding Meyer as a leper, I am not recommending that he should be kept at a distance; all I am saying is that he has to take another two or three steps forward if he wants to identify himself completely with the position of the present Central Committee of the German Communist Party.
# Predicted Persian: هنوز به اندازه‌ای دور از سمت راست به سمت کمیته مرکزی حزب کمونیست آلمان نرفته است که بتوان به او رسیدگی کرد به جایگاهی که در حال حاضر رهبری حزب کمونیست آلمان را دارد. من از مایر به عنوان یک زار از من گریز نمی‌کنم، توصیه نمی‌کنم که او را دور نگه داریم؛ فقط می‌گویم که برای اینکه به طور کامل با جایگاه کمیته مرکزی حزب کمونیست آلمان خود را
# Actual Persian: او هنوز باید دو یا سه قدم دیگر از حقوق ها به سمت کمیته مرکزی فاصله بگیرد تا به موقعیت رهبری فعلی حزب کمونیست آلمان برسد . من دور از تلقی مایر به عنوان یک جذامی هستم . تنها چیزی که می گویم این است که اگر بخواهد خود را کاملا با موضع کمیته مرکزی فعلی حزب کمونیست آلمان شناسایی کند ، باید دو یا سه قدم دیگر به جلو بردارد .
#
# --- Sample 28 ---
# Original English: Liam is a cosy wooden playhouse with infinite possibilities!
# Predicted Persian: لیام یک خانه‌ی بازی چوبی دنج با امکانات بی‌شماری است!
# Actual Persian: لیام یک خانه بازی چوبی دنج با امکانات بی نهایت است !
#
# --- Sample 29 ---
# Original English: do you usually leave it to the porter to tell you this sort of things only when its a necessary brief .
# Predicted Persian: معمولاً این‌گونه چیزها را به پرتور می‌فرستید، فقط وقتی ضروری است؟
# Actual Persian: آیا معمولا آن را به باربر می سپارید که این جور چیزها را فقط در مواقع ضروری به شما بگوید ؟
#
# --- Sample 30 ---
# Original English: hey , can i have some of that .
# Predicted Persian: ببخشید، میشه یه کم ازش برام بدی؟
# Actual Persian: هی ، آیا می توانم مقداری از آن را داشته باشم .
#
# --- Sample 31 ---
# Original English: While she was playing the field, she realized that beauty is in the eye of the beholder, and that life is too short to sweat the small stuff.
# Predicted Persian: در حالی که در حال بازی در میان مردان بود، فهمید که زیبایی در چشمِ دیدگار است و زندگی کوتاه است تا در مسائل کوچک غرور کند.
# Actual Persian: در حالی که او در حال تجربه کردن زندگی و روابط مختلف بود ، متوجه شد که زیبایی نسبی است و زندگی آنقدر کوتاه است که نباید به چیزهای جزئی اهمیت داد .
#
# --- Sample 32 ---
# Original English: Puigcerda 872095 *** Phone
# Predicted Persian: پوئِگِردا 872095 * تلفن
# Actual Persian: Puigcerda 872095 *** تلفن
#
# --- Sample 33 ---
# Original English: That feels weird and good all at once.
# Predicted Persian: همزمان حس عجیبی و خوبی داره.
# Actual Persian: این همزمان عجیب و خوب به نظر می رسد .
#
# --- Sample 34 ---
# Original English: Before you can open a X10 file, you'll need to figure out what kind of file the X10 file extension refers to. Tip: Incorrect X10 file association errors can be a symptom of other underlying issues within your Windows operating system.
# Predicted Persian: برای باز کردن فایل X10، ابتدا باید بفهمید که این فایل به چه نوعی اشاره دارد. نکته‌ی مهم: خطای اشتباه متعلق به فایل X10 می‌تواند نشانه‌ای از مشکلات اساسی در سیستم عامل ویندوز شما باشد.
# Actual Persian: قبل از اینکه بتوانید یک فایل X10 را باز کنید ، باید بفهمید پسوند فایل X10 به چه نوع فایلی اشاره دارد . نکته : خطاهای مرتبط با فایل X10 نادرست می تواند نشانه سایر مشکلات اساسی در سیستم عامل ویندوز شما باشد .
#
# --- Sample 35 ---
# Original English: You shall be cursed when you come in, and you shall be cursed when you go out.
# Predicted Persian: وقتی وارد شوی، نفرین می‌شوی و وقتی بیرون می‌روی، نفرین.
# Actual Persian: وقتی وارد می شوید نفرین می شوید و وقتی بیرون می روید نفرین خواهید شد .
#
# --- Sample 36 ---
# Original English: Only upon expiry thereof Russia will be able to address the WTO with the proposed sanctions, which will be approved in about two or three months' time.
# Predicted Persian: فقط پس از انقضا آن، روسیه قادر خواهد بود با پیشنهادات نزاع جهانی (WTO) با آن برخورد کند که در حدود دو یا سه ماه آینده تصویب خواهد شد.
# Actual Persian: تنها پس از انقضای آن ، روسیه می تواند با تحریم های پیشنهادی به سازمان تجارت جهانی که حدود دو یا سه ماه دیگر تصویب می شود ، رسیدگی کند .
#
# --- Sample 37 ---
# Original English: id246661099
# Predicted Persian: id246661099
# Actual Persian: id246661099
#
# --- Sample 38 ---
# Original English: hes devastated aboutmissing his big singing debut. .
# Predicted Persian: او از دست دادن اولین اجرای بزرگش برای خوانندگی بسیار داغدار است.
# Actual Persian: او از این که اولین خوانندگی بزرگ خود را از دست داده است ناراحت است . .
#
# --- Sample 39 ---
# Original English: It is currently Mon May 23, 2016 7:37 pm
# Predicted Persian: در حال حاضر پنجشنبه ۲۳ اردیبهشت ۱۳۹۵ ۱۹:۳۷ بعد از ظهر
# Actual Persian: در حال حاضر دوشنبه 23 می 2016 ، ساعت 19 : 37 است
#
# --- Sample 40 ---
# Original English: Bouches-Du-Rhone 432 ****** Phone
# Predicted Persian: Bouches-Du-Rhone 432 -****** تلفن
# Actual Persian: Bouches - Du - Rhone 432 ****** تلفن
#
# --- Sample 41 ---
# Original English: She had actually taken tea with the Yankee officers' wives in their homes!
# Predicted Persian: او در واقع با همسرهای افسرهای یانی در خانه‌شان چای خورده بود!
# Actual Persian: او در واقع با همسران افسران یانکی در خانه هایشان چای خورده بود !
#
# --- Sample 42 ---
# Original English: Caldwell (New Jersey) 973865 **** Mobile
# Predicted Persian: کالدول (نیوجرسی) 973865 **** موبایل
# Actual Persian: کالدول ( نیوجرسی ) 973865 **** موبایل
#
# --- Sample 43 ---
# Original English: If you are a little pressed for time, we have a three day version of this Grand Canyon tour from Los Angeles. Instead of flying to Las Vegas for the night first, and starting your tour there the next day, you can go directly to the Grand Canyon on the first day of the tour. Please check out the three day version of this tour.
# Predicted Persian: اگر کمی وقت کم دارید، یک تور سه روزه از کانیان بزرگ از لس‌آنجلس داریم. به جای اینکه اول شب به لاس وگاس بروید و روز بعد از آنجا شروع به سفر کنید، می‌توانید مستقیماً در روز اول این تور به کانیان بزرگ بروید. لطفاً نسخه سه روزه این تور را بررسی کنید.
# Actual Persian: اگر کمی به زمان نیاز دارید ، ما یک نسخه سه روزه از این تور گرند کنیون از لس آنجلس را داریم . به جای اینکه ابتدا برای شب به لاس وگاس پرواز کنید و روز بعد تور خود را از آنجا شروع کنید ، می توانید در روز اول تور مستقیما به گرند کنیون بروید . لطفا نسخه سه روزه این تور را بررسی کنید .
#
# --- Sample 44 ---
# Original English: Solar panels on Massachusetts homes have become more common since the utilization of ARRA funds for the State Energy Program. Remember the massive economic stimulus bill that the U.S. Congress passed in February 2009?
# Predicted Persian: پنل‌های خورشیدی در خانه‌های ماساچوست از زمان استفاده از بودجه آرآرای برای برنامه انرژی ایالتی، رایج‌تر شده‌اند. یادآوری کنید که قانونی بزرگ برای تسهیلات اقتصادی در سال ۲۰۰۹، که کنگره آمریکا تصویب کرد، چه بود؟
# Actual Persian: پانل های خورشیدی در خانه های ماساچوست از زمان استفاده از بودجه ARRA برای برنامه انرژی ایالتی رایج تر شده اند . لایحه عظیم محرک اقتصادی را که کنگره ایالات متحده در فوریه 2009 تصویب کرد ، به خاطر دارید ؟
#
# --- Sample 45 ---
# Original English: Article 52. Providing Gowns to Judges
# Predicted Persian: مصرف لباس در دادگاه.
# Actual Persian: ماده 52 . ارائه لباس به قضات
#
# --- Sample 46 ---
# Original English: If you have just started to play game and you don't want to invest your hard earned yet than this portals is really for you and your friends. You can choose five or even six free bonus offers to play internet poker and learn a trick or two before you purchase your cash.
# Predicted Persian: اگر تازه شروع به بازی کرده‌اید و هنوز پول زیادی برای سرمایه‌گذاری نداشته‌اید، این پورتال برای شما و دوستانتان است. می‌توانید پنج یا حتی شش پیشنهاد رایگان بازی پوکر اینترنت را انتخاب کنید تا قبل از خرید پول نقد، یک یا دو ترفند را یاد بگیرید.
# Actual Persian: اگر به تازگی بازی را شروع کرده اید و هنوز نمی خواهید به سختی به دست آورده اید سرمایه گذاری کنید ، این پورتال واقعا برای شما و دوستانتان است . شما می توانید پنج یا حتی شش پیشنهاد جایزه رایگان را برای بازی پوکر اینترنتی انتخاب کنید و قبل از خرید پول نقد خود ، یک یا دو ترفند یاد بگیرید .
#
# --- Sample 47 ---
# Original English: "At the same time, it will pay principal payments, respectively, these payments will become more assured and more value for the farmers"", he has added."
# Predicted Persian: همچنین، در این زمان، وجه‌های اصلی پرداخت خواهد شد، به این ترتیب، این پرداخت‌ها تضمین‌شده‌تر و برای کشاورزان ارزشمندتر خواهند شد.
# Actual Persian: وی افزود : در عین حال اصل پرداخت را نیز پرداخت می کند و این پرداخت ها برای کشاورزان مطمئن تر و ارزش بیشتری خواهد داشت .
#
# --- Sample 48 ---
# Original English: 'Have you got any string? ' I said.
# Predicted Persian: بافت دارید؟ پرسیدم.
# Actual Persian: آیا رشته ای دارید ؟ ' گفتم .
#
# --- Sample 49 ---
# Original English: Did he bathe him and dress him
# Predicted Persian: او او را حمام کرد و لباس پوشاند؟
# Actual Persian: آیا او را غسل داد و لباس پوشید
#
# --- Sample 50 ---
# Original English: This is not the time for your linear mind.
# Predicted Persian: این زمان ذهنی رگرسوندی نیست.
# Actual Persian: اکنون زمان ذهن خطی شما نیست .
#
# --- Sample 51 ---
# Original English: Every assassination only makes the police more vicious and the people more accustomed to violence and brutality
# Predicted Persian: هر قتل‌عام، پلیس را جهنمی‌تر و مردم را به خشونت و بی‌رحمی عادت‌تر می‌کند
# Actual Persian: هر ترور فقط پلیس را شریرتر می کند و مردم را به خشونت و بی رحمی عادت می دهد .
#
# --- Sample 52 ---
# Original English: Category: the 6th International
# Predicted Persian: کد: ۶۷
# Actual Persian: دسته : ششمین بین المللی
#
# --- Sample 53 ---
# Original English: if love be rough with you , be rough with love .
# Predicted Persian: اگر عشق با تو سخت باشد، با عشق سخت باش.
# Actual Persian: اگر عشق با تو خشن است با عشق خشن باش .
#
# --- Sample 54 ---
# Original English: There's only a problem...
# Predicted Persian: فقط یک مشکل وجود دارد...
# Actual Persian: مشکل فقط وقتیه که
#
# --- Sample 55 ---
# Original English: The image looks gloomy.
# Predicted Persian: عکس غمگین به نظر می‌رسد.
# Actual Persian: تصویر تاریک به نظر می رسد .
#
# --- Sample 56 ---
# Original English: Elefanten Press, Berlin, 2000
# Predicted Persian: Elefanten Press، برلین، ۲۰۰۰
# Actual Persian: Elefanten Press ، برلین ، 2000
#
# --- Sample 57 ---
# Original English: No word on any other changes in the 1.0.1 version of evasi0n7.
# Predicted Persian: هیچ اظهارنی در مورد تغییرات دیگری در نسخه 1.0.1 از افسایو7.
# Actual Persian: هیچ خبری در مورد تغییرات دیگری در نسخه 1.0.1 evasi0n7 وجود ندارد .
#
# --- Sample 58 ---
# Original English: Hence the ready-made formula: feudal survivals, hence also the struggle of the peasantry against feudal survivals, are of no serious importance in the Chinese revolution, and that the chief thing in China today is not the agrarian revolution, but the question of China's state-customs dependence on the imperialist countries.
# Predicted Persian: بنابراین، فرمول آماده: بقایای فئودال، از این‌جا هم مبارزه دهقانان با بقایای فئودالیست، اهمیت جدی‌ای در انقلاب چین ندارد، و مهم‌ترین چیز در چین امروز، نیازمندی چین به تجارت‌محوریت کشورهای امپریالیستی نیست، بلکه مسئله وابستگی چین به رسمیت‌های دولتی به کشورهای امپریالیستی است.
# Actual Persian: از این رو فرمول آماده : بقای فئودالی ، از این رو مبارزه دهقانان علیه بقای فئودالی ، در انقلاب چین اهمیتی جدی ندارد ، و اینکه مهمترین چیز در چین امروز انقلاب ارضی نیست ، بلکه مسئله چین است . وابستگی گمرکی دولت به کشورهای امپریالیستی
#
# --- Sample 59 ---
# Original English: although he knew that his whole future depended on her character and reputation.
# Predicted Persian: با اینکه می‌دانست آینده‌ی کاملش به شخصیت و شهرت او بستگی دارد.
# Actual Persian: اگرچه می دانست که تمام آینده اش به شخصیت و شهرت او بستگی دارد .
#
# --- Sample 60 ---
# Original English: for Janni was physically precocious and had quickly taken the leadership of the pair.
# Predicted Persian: برای جانی، پنهان‌کار بود و به سرعت رهبری آن دو را به دست آورده بود.
# Actual Persian: زیرا جانی از نظر بدنی زودرس بود و به سرعت رهبری این زوج را به دست گرفته بود .
#
# --- Sample 61 ---
# Original English: we've been in here a long time.
# Predicted Persian: ما مدت زیادی اینجا بوده‌ایم.
# Actual Persian: ما خیلی وقته اینجا بوده ایم
#
# --- Sample 62 ---
# Original English: When the Archduchess Harriet Griselda stooped to fasten the buckle
# Predicted Persian: وقتی ارشمودی هریت گرسیلدا برای بستن گره، خم شد.
# Actual Persian: وقتی آرکدوشس هریت گریزلدا خم شد تا سگک را ببندد
#
# --- Sample 63 ---
# Original English: Chicago (Illinois) 312867 **** Phone
# Predicted Persian: شیکاگو (ایلی‌نوی) 312867 **** تلفن
# Actual Persian: شیکاگو ( ایلینوی ) 312867 **** تلفن
#
# --- Sample 64 ---
# Original English: 1. The Evidences of Early Christian Writings
# Predicted Persian: 1. شواهد آثار اولیه‌ی مسیحیان اولیه
# 2. شواهد آثار اولیه‌ی مسیحیان اولیه (اصول مسیحیه)
# Actual Persian: 1 . شواهد نوشته های اولیه مسیحیت
#
# --- Sample 65 ---
# Original English: - I would like to express my deep gratitude, as the Pontifical Council's secretary for Sacred Archaeology, to President of the Heydar Aliyev Foundation, doctor Mrs. Mehriban Aliyeva, who will support the works to be carried out for the restoration of Sacred Marcellino and Pietro catacombs, financing of these works, doing a very well-wishing work.
# Predicted Persian: با احترام و قدردانی عمیق، از شما، رئیس شورای کلیسای پاپ، دکتر مهربان علی‌علی‌یه، خواهشمندم که در حال حاضر، ایشان را به عنوان رئیس هیئت امنای سازمان صحرای مقدس ماری‌مارسینو و پیتر و همچنین به صورت فداکاری، از اقدامات انجام شده در مورد بازسازی کلیساهای مقدس ماری‌مارسینو و پی
# Actual Persian: - مایلم به عنوان دبیر باستان شناسی مقدس شورای پاپی از رئیس بنیاد حیدر علی اف ، دکتر خانم مهریبان علیوا ، که از کارهایی که قرار است برای مرمت مقدس مارسلینو و پیترو انجام شود حمایت خواهد کرد ، عمیقا تشکر کنم . دخمه ها ، تامین مالی این آثار ، انجام یک کار بسیار خیرخواهانه .
#
# --- Sample 66 ---
# Original English: Organizer of the assembly conducted without prior notification, is criminally liable and may be punished in the form of deprivation of liberty up to one year or a fine (Article 26 Paragraph 2).
# Predicted Persian: مقام برگزاری گردهمایی بدون اطلاع‌رسانی پیشگیرانه، مجرم است و ممکن است به شکل محرومیت از آزادی تا یک سال یا جریمه مجازات شود (آیین‌نامه ۲۶، بند ۲).
# Actual Persian: برگزارکننده مجمعی که بدون اطلاع قبلی برگزار می شود ، مسئولیت کیفری دارد و ممکن است به مجازات محرومیت از آزادی تا یک سال یا جزای نقدی محکوم شود ( بند 2 ماده 26 ).
#
# --- Sample 67 ---
# Original English: "Japanese film ""Hachimitsu to kuroba"" (2006)"
# Predicted Persian: فیلم ژاپنی "هچیمسوتو و کوروبا" (۲۰۰۶)
# Actual Persian: " Japanese film "" Hachimitsu to kuroba "" ( 2006 )"
#
# --- Sample 68 ---
# Original English: You and Miss Fairfax gave us some very good music.
# Predicted Persian: شما و خانم فیرفاکس موسیقی خیلی خوبی به ما دادید.
# Actual Persian: شما و خانم فیرفکس چند آهنگ خیلی خوب به ما دادید .
#
# --- Sample 69 ---
# Original English: what did you say your name was l didnt .
# Predicted Persian: اسم خودت چی بود؟ نداشتم.
# Actual Persian: گفتی اسمت چی بود من نفهمیدم
#
# --- Sample 70 ---
# Original English: LanSAages: Kazakh, Russian
# Predicted Persian: زبان‌های لانزایی: قزاقستانی، روسی
# Actual Persian: LanSAages : قزاق ، روسی
#
# --- Sample 71 ---
# Original English: 15 And the children of the Levites bare the ark of God upon their shoulders with the staves thereon, as Moses commanded according to the word of the LORD.
# Predicted Persian: ۱۵ و فرزندان لوویا ارک خدا را بر دوش خود با چوب‌هایی که بر آن بود، چنان که موسی بر اساس فرمان خداوند عمل کرد.
# Actual Persian: 15 و بنی لاویان تابوت خدا را بر شانه های خود با چوب هایی بر آن حمل کردند ، چنانکه موسی برحسب کلام خداوند امر فرمود .
#
# --- Sample 72 ---
# Original English: while they are yet speaking, I will hear.
# Predicted Persian: در حین صحبت کردن، من می‌شنوم.
# Actual Persian: در حالی که آن ها هنوز صحبت می کنند ، من خواهم شنید .
#
# --- Sample 73 ---
# Original English: Tel.: +996 (559) 700 013
# Predicted Persian: تلفن: +996 (559) 700 013
# Actual Persian: تلفن : + 996 ( 559 ) 700 013
#
# --- Sample 74 ---
# Original English: Cuba's President Raul Castro's speech at the close of Cuba's National Assembly session
# Predicted Persian: سخنرانی رئیس جمهور رائول کاسترو در پایان جلسه مجلس ملی کوبا
# Actual Persian: سخنرانی رائول کاسترو رئیس جمهور کوبا در پایان نشست مجلس ملی کوبا
#
# --- Sample 75 ---
# Original English: "We know from history how the financial bosses of France, by appointing ""Socialists"" (Briand! Viviani!) to the head of cabinets, while themselves hiding behind their backs, have successfully carried out the policy of their class."
# Predicted Persian: از تاریخ می‌دانیم که چطور رئیسان مالی فرانسه با اعزام «سوسالیزم‌ها» (بیان! وویویانی!) به سمت وزیران، در حالی که خودشان پشت سرشان پنهان می‌شدند، سیاستِ طبقه‌ی خود را به موفقیت رسانده‌اند.
# Actual Persian: ما از تاریخ می دانیم که چگونه روسای مالی فرانسه با انتصاب « سوسیالیست ها » ( برایاند ! ویویانی !) به ریاست کابینه ها ، در حالی که خود را پشت سر خود پنهان کرده اند ، با موفقیت سیاست طبقه خود را اجرا کرده اند ».
#
# --- Sample 76 ---
# Original English: Even though I prefer to fly by the seat of my pants when tackling new projects, I know I need to take it easy and trust the process to avoid burning the candle at both ends.
# Predicted Persian: با اینکه ترجیح می‌دهم در پروژه‌های جدید بدون برنامه و با ایده‌های خودم پیش بروم، می‌دانم که باید استراحت کنم و به فرآیند اعتماد کنم تا از سوختن شمع در هر دو طرف جلوگیری کنم.
# Actual Persian: با اینکه من تمایل دارم به صورت خودجوش و بداهه به پروژه های جدید بپردازم ، می دانم که باید آرام باشم و به روند کار اعتماد کنم تا از فرسودگی و خستگی زیاد جلوگیری کنم .
#
# --- Sample 77 ---
# Original English: When in Babylon the three young men Shadrach, Meshach und Abed'nego because of their faithfulness were thrown into the fiery furnace, Daniel was absent (Daniel 3).
# Predicted Persian: وقتی آن‌ها به بابله بودند، سه جوان شادریک، مشاخ و ابد‌نقی به دلیل وفاداری‌شان در آتش فندک انداخته شدند (دانيل 3).
# Actual Persian: هنگامی که در بابل ، سه مرد جوان ، شدرک ، میشاخ و عابدنگو به دلیل وفاداریشان به کوره آتشین انداخته شدند ، دانیال غایب بود ( دانیال 3 ).
#
# --- Sample 78 ---
# Original English: 0 2,061
# Predicted Persian: 0 2,061
# Actual Persian: 0 2 ، 061
#
# --- Sample 79 ---
# Original English: you know how i got these animals on wall .
# Predicted Persian: می‌دونی چطور این حیوانات رو روی دیوار گذاشتم.
# Actual Persian: میدونی چطوری این حیوانات رو روی دیوار انداختم
#
# --- Sample 80 ---
# Original English: Also, during the meeting with President of Guinea Alpha Conde, the Head of State noted the importance of the Summit of the Organization of Islamic Cooperation in science and technology for the entire Islamic world.
# Predicted Persian: در طول جلسه با رئیس جمهور گینه، رئیس‌جمهور، اهمیت سِموم سازمان همکاری اسلامی در علم و فناوری را برای کل جهان اسلامی تأکید کرد.
# Actual Persian: همچنین رئیس جمهور در دیدار با رئیس جمهور گینه آلفا کوند ، بر اهمیت اجلاس سران سازمان همکاری اسلامی در علم و فناوری برای کل جهان اسلام تاکید کرد .
#
# --- Sample 81 ---
# Original English: Step 1. Open yet another image in the program - a duet of modern dancers.
# Predicted Persian: تعداد یک: باز کردن یک تصویر دیگر در برنامه - یک دوتا از رقصندگان مدرن.
# Actual Persian: مرحله 1 . تصویر دیگری را در برنامه باز کنید - دوئت رقصندگان مدرن .
#
# --- Sample 82 ---
# Original English: "Also, a wide range of products under the brand ""Chabrec"" (thyme) and ""Rola"" were presented. As a result of negotiations, Afghan businessmen signed an agreement on direct deliveries of goods, and offered to be an exclusive distributor in Afghanistan."
# Predicted Persian: در ضمن، طیف گسترده‌ای از محصولات تحت برند «چابره» (یالو) و «رولا» ارائه شد. در نتیجه مذاکرات، تاجرهای افغانی به توافق رسیدند که واردات مستقیم کالاها را به صورت مستقیم انجام دهند و پیشنهاد کردند که به عنوان یک توزیع‌کننده ویژه در افغانستان فعالیت کنند.
# Actual Persian: همچنین ، طیف وسیعی از محصولات با نام تجاری " چابرک " ( آویشن ) و " رولا " ارائه شد که در نتیجه مذاکرات ، تجار افغان توافقنامه ای را در مورد تحویل مستقیم کالا امضا کردند و پیشنهاد کردند که یک توزیع کننده انحصاری در افغانستان ."
#
# --- Sample 83 ---
# Original English: Winsted (Connecticut) 860738 **** Phone Niantic (Connecticut) 860739 **** Phone
# Predicted Persian: وینستد (کنnecticut) 860738 **** تلفن نیانتیک (کنnecticut) 860739 **** تلفن
# Actual Persian: Winsted ( Connecticut ) 860738 **** Phone Niantic ( Connecticut ) 860739 **** Phone
#
# --- Sample 84 ---
# Original English: 43.90% more battery power
# Predicted Persian: 43.90 درصد بیشتر باتری
# Actual Persian: 43.90٪ قدرت باتری بیشتر
#
# --- Sample 85 ---
# Original English: And then, unexpectedly, two seconds later, the procession did halt.
# Predicted Persian: و سپس، ناگهان، دو ثانیه بعد، دسته‌بندی متوقف شد.
# Actual Persian: و سپس ، به طور غیرمنتظره ، دو ثانیه بعد ، راهپیمایی متوقف شد .
#
# --- Sample 86 ---
# Original English: I do not think so.
# Predicted Persian: فکر نمی‌کنم.
# Actual Persian: من اینطور فکر نمی کنم .
#
# --- Sample 87 ---
# Original English: the habitual residence of the person concerned at the time of State succession;
# Predicted Persian: محل سکونت شاغل در زمان به دست گرفتن مقام دولت؛
# Actual Persian: اقامتگاه عادی شخص مربوطه در زمان جانشینی دولت ؛
#
# --- Sample 88 ---
# Original English: economist, minister, Ministry of Transport and Road Infrastructure
# Predicted Persian: اقتصاددان، وزیر، وزارت حمل و نقل و زیرساخت‌های راه‌آهن
# Actual Persian: اقتصاددان ، وزیر ، وزارت حمل ونقل و زیرساخت های جاده ای
#
# --- Sample 89 ---
# Original English: It was a long while since he had taken vodka and it had an effect upon him at once, though he only drank a wineglassful.
# Predicted Persian: مدت زیادی از آخرین بار که ودکا نوشیده بود می‌گذشت و بلافاصله اثرش روی او بود، اگرچه فقط یک لیوان شراب نوشید.
# Actual Persian: مدت زیادی بود که ودکا نخورده بود و یکباره روی او اثر گذاشت ، هرچند او فقط یک لیوان شراب نوشید .
#
# --- Sample 90 ---
# Original English: How are you, boys?
# Predicted Persian: حالتون چطوره، بچه‌ها؟
# Actual Persian: حالتون چطوره پسرا
#
# --- Sample 91 ---
# Original English: Our Intellectual Property
# Predicted Persian: حقوق معنوی ما
# Actual Persian: مالکیت معنوی ما
#
# --- Sample 92 ---
# Original English: The rules are easy to learn and with the assistance of our guide, you'll be playing in no time.
# Predicted Persian: قوانین یادگیری آسان است و با کمک راهنمای ما، به زودی در بازی خواهید بود.
# Actual Persian: یادگیری قوانین آسان است و با کمک راهنمای ما ، در کمترین زمان بازی خواهید کرد .
#
# --- Sample 93 ---
# Original English: The eight global finalists should be announced in July 2011. The Australian winner will be announced in August 2011.
# Predicted Persian: هشت نهایی جهانی باید در ماه ژوئیه ۲۰۱۱ اعلام شوند. برنده استرالیا در ماه اوت ۲۰۱۱ اعلام خواهد شد.
# Actual Persian: هشت فینالیست جهانی باید در جولای 2011 معرفی شوند . برنده استرالیایی در آگوست 2011 معرفی خواهد شد .
#
# --- Sample 94 ---
# Original English: Whatever the cause, you should know that God hates divorce and says:
# Predicted Persian: هر چه دلیلش باشد، باید بدانید که خدا از طلاق نفرت دارد و می‌گوید:
# Actual Persian: علتش هرچه که باشد باید بدانید که خداوند از طلاق بیزار است و می فرماید :
#
# --- Sample 95 ---
# Original English: As the Deputy of the regional maslikhat noted, any Kazakhstani citizen having his own civil position can also become a member of the working expert group.
# Predicted Persian: به گفتهٔ منشی ناحیهٔ مسلخات، هر کس که مقام مدنی خود را داشته باشد می‌تواند عضو گروه کارشناس کارگزینی نیز شود.
# Actual Persian: همان طور که معاون مسلخات منطقه ای خاطرنشان کرد ، هر شهروند قزاقستانی که موقعیت مدنی خود را دارد نیز می تواند به عضویت گروه کارشناس درآید .
#
# --- Sample 96 ---
# Original English: Grandpa is not feeling well enough to take me.
# Predicted Persian: پدربزرگ حالش خوب نیست که منو ببره.
# Actual Persian: حال پدربزرگ آنقدر خوب نیست که مرا ببرد .
#
# --- Sample 97 ---
# Original English: It is vital for the university's academic community to have access to training infrastructure based on a web engineering laboratory. The new laboratory is being designed for students' practical assignments, scientific research and professional development in the field of web technology. It requires close partnership with IT companies in which businesses get engaged in the training process and experience sharing.
# Predicted Persian: برای جامعه‌ی علمی دانشگاه، داشتن دسترسی به زیرساخت‌های آموزشی بر اساس یک آزمایشگاه مهندسی وب حیاتی است. آزمایشگاه جدید برای انجام تکالیف عملی، تحقیقات علمی و توسعه‌ی حرفه‌ای در زمینه‌ی فناوری‌های وب طراحی می‌شود. این آزمایشگاه نیازمند مشارکت نزدیک با شرکت‌های فناوری اطلاعاتی است که در این فرآیند آموزش شرکت می‌کنند و از تجربیات یکدیگر بهره‌مند می‌شوند.
# Actual Persian: دسترسی جامعه آکادمیک دانشگاه به زیرساخت های آموزشی مبتنی بر آزمایشگاه مهندسی وب حیاتی است . آزمایشگاه جدید برای انجام تکالیف عملی دانشجویان ، تحقیقات علمی و توسعه حرفه ای در زمینه فناوری وب طراحی شده است . این امر مستلزم مشارکت نزدیک با شرکت های فناوری اطلاعات است که در آن کسب وکارها درگیر فرآیند آموزش و به اشتراک گذاری تجربه می شوند .
#
# --- Sample 98 ---
# Original English: We are looking forward to getting to know you!
# Predicted Persian: به شناخت شما مشتاقیم!
# Actual Persian: ما مشتاقانه منتظر آشنایی شما هستیم !
#
# --- Sample 99 ---
# Original English: New Orleans (Louisiana) 504310 **** Phone
# Predicted Persian: ناوورث (لیونزئولا) 504310 **** تلفن
# Actual Persian: نیواورلئان ( لوئیزیانا ) 504310 **** تلفن
#
# --- Sample 100 ---
# Original English: james , you cant kiii me .
# Predicted Persian: جیمز، نمی‌تونی منو کِییی کنی.
# Actual Persian: جیمز تو نمیتونی منو بپذیری
#
# Generated 100 Persian translations.

# %%
# !pip install evaluate bert_score
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.12/dist-packages (0.4.6)
# Requirement already satisfied: bert_score in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.9.0+cu126)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert_score) (4.57.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert_score) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2025.11.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (3.2.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.3)

# %% [markdown]
# # Task
# Calculate BLEU, CHRF++, and BERTScore metrics for the 10 generated predictions (`generated_persian_texts`) against their corresponding reference target language sentences (`target_texts[:10]`) and present the results.

# %% [markdown]
# ## Calculate BLEU Score
#
# ### Subtask:
# Compute the BLEU score between the 10 generated predictions and the corresponding reference target language sentences.

# %% [markdown]
# **Reasoning**:
# I will import the `evaluate` library, load the 'bleu' metric, prepare the `generated_persian_texts` and `target_texts` for the first 10 samples in the correct format, compute the BLEU score, and then print it.

# %%
import evaluate

# Load the BLEU metric
bleu = evaluate.load("bleu")

# Prepare references: each reference needs to be in a list
# We generated only 10 predictions, so we take the first 100 target texts.
references_for_bleu = [[text] for text in target_texts[:100]]

# Compute BLEU score
results = bleu.compute(predictions=generated_persian_texts, references=references_for_bleu)

# Print the BLEU score
print("BLEU score:", results["bleu"])
# Out:
# BLEU score: 0.0044026828556608215

# %%
import evaluate

#!pip install sacrebleu

# Load the CHRF++ metric
chrf = evaluate.load("chrf")

# Prepare references: each reference needs to be in a list
# We generated only 10 predictions, so we take the first 100 target texts.
# The CHRF++ metric expects references as a list of lists of strings, just like BLEU.
references_for_chrf = [[text] for text in target_texts[:100]]

# Compute CHRF++ score
chrf_results = chrf.compute(predictions=generated_persian_texts, references=references_for_chrf)

# Print the CHRF++ score
print("CHRF++ score:", chrf_results["score"])
# Out:
# CHRF++ score: 7.6024692349810294

# %% [markdown]
# **Reasoning**:
# With BLEU and CHRF++ scores calculated, the next step is to compute the BERTScore for the 10 generated predictions against their corresponding reference target language sentences. This will involve loading the 'bertscore' metric from the `evaluate` library, ensuring the references are in the correct format, computing the score, and then printing the result.

# %%
import evaluate

# Load the BERTScore metric
bertscore = evaluate.load("bertscore")

# Prepare references: each reference needs to be in a list
# We generated only 10 predictions, so we take the first 100 target texts.
# BERTScore expects references as a list of lists of strings, similar to BLEU/CHRF++
references_for_bertscore = [[text] for text in target_texts[:100]]

# Compute BERTScore
bertscore_results = bertscore.compute(
    predictions=generated_persian_texts,
    references=references_for_bertscore,
    lang="fa" # Specify the language as Persian
)

# Print the BERTScore results (P, R, F1)
print("BERTScore Precision:", bertscore_results["precision"])
print("BERTScore Recall:", bertscore_results["recall"])
print("BERTScore F1:", bertscore_results["f1"])
# Out:
# BERTScore Precision: [0.6287417411804199, 0.6803514361381531, 0.6054458618164062, 0.5365273952484131, 0.6286966800689697, 0.6461114287376404, 0.7391335964202881, 0.6548765897750854, 0.7087835073471069, 0.623328447341919, 0.5369585156440735, 0.6535769104957581, 0.43197041749954224, 0.6227776408195496, 0.7288725972175598, 0.598240315914154, 0.6820625066757202, 0.580910325050354, 0.5808415412902832, 0.5924385786056519, 0.6192103028297424, 0.5028626322746277, 0.5990843772888184, 0.6556053161621094, 0.5775143504142761, 0.686211884021759, 0.5187636613845825, 0.6389246582984924, 0.6780828237533569, 0.6063700318336487, 0.6839640736579895, 0.5872628688812256, 0.6212063431739807, 0.6209208369255066, 0.6213726997375488, 0.608467698097229, 0.5088251829147339, 0.6929677724838257, 0.5036611557006836, 0.5510408878326416, 0.626553475856781, 0.5942873954772949, 0.5757968425750732, 0.6346117258071899, 0.6681174039840698, 0.6149377226829529, 0.5847890377044678, 0.6771902441978455, 0.7102380394935608, 0.6595187187194824, 0.6399205923080444, 0.6172260046005249, 0.6561006903648376, 0.5778826475143433, 0.6817688345909119, 0.5509012937545776, 0.6219542622566223, 0.525399923324585, 0.6532777547836304, 0.6461120247840881, 0.644458532333374, 0.6421362161636353, 0.569706916809082, 0.5992940664291382, 0.5846189260482788, 0.5510561466217041, 0.6084267497062683, 0.6969403028488159, 0.6850509643554688, 0.5315147638320923, 0.5904377698898315, 0.6077975034713745, 0.5923281311988831, 0.6265632510185242, 0.6030633449554443, 0.6118420362472534, 0.5805299282073975, 0.5642217993736267, 0.8522894382476807, 0.6256646513938904, 0.6433055400848389, 0.5214264392852783, 0.5101425647735596, 0.5964249968528748, 0.6141700744628906, 0.6570488810539246, 0.6038950085639954, 0.6788597702980042, 0.5825923681259155, 0.586862325668335, 0.6929341554641724, 0.6196578741073608, 0.6524903774261475, 0.6381903290748596, 0.6613869071006775, 0.7307077646255493, 0.5887712240219116, 0.6715990304946899, 0.5905994176864624, 0.5942079424858093]
# BERTScore Recall: [0.6563256978988647, 0.5778214335441589, 0.6124875545501709, 0.6091867685317993, 0.5747285485267639, 0.6654610633850098, 0.7409493327140808, 0.6303985714912415, 0.7041235566139221, 0.50493323802948, 0.5832070112228394, 0.6131682991981506, 0.5193278193473816, 0.6415994763374329, 0.710817813873291, 0.6378244161605835, 0.6492112874984741, 0.6633995175361633, 0.6174606084823608, 0.4505488872528076, 0.6346275806427002, 0.6034811735153198, 0.6308618187904358, 0.611392617225647, 0.5800849199295044, 0.5593648552894592, 0.611871063709259, 0.637271523475647, 0.6390938758850098, 0.5986551642417908, 0.6581317186355591, 0.6318252086639404, 0.5616455674171448, 0.6393722295761108, 0.5831507444381714, 0.6497567892074585, 0.5168312788009644, 0.6953188180923462, 0.601688802242279, 0.6052942276000977, 0.6338359713554382, 0.5929848551750183, 0.6390905380249023, 0.6699584126472473, 0.5528638362884521, 0.6679803133010864, 0.6221032738685608, 0.6118686199188232, 0.6965141892433167, 0.54931640625, 0.6058940291404724, 0.5967813730239868, 0.5925906896591187, 0.5700893998146057, 0.6206098198890686, 0.5437719821929932, 0.6111921072006226, 0.5810292959213257, 0.5854703187942505, 0.6258825659751892, 0.6249169111251831, 0.6083343029022217, 0.654596209526062, 0.6027795672416687, 0.6534062027931213, 0.5827394723892212, 0.6163004636764526, 0.6846056580543518, 0.6427465677261353, 0.5074905157089233, 0.5627471804618835, 0.5657646656036377, 0.5683350563049316, 0.6592923998832703, 0.65287846326828, 0.6376341581344604, 0.6331848502159119, 0.5494492053985596, 0.8654597401618958, 0.6110897064208984, 0.5694129467010498, 0.47409504652023315, 0.551701545715332, 0.5414129495620728, 0.6688082218170166, 0.6442588567733765, 0.6577767133712769, 0.6686964631080627, 0.5869531631469727, 0.5930564403533936, 0.6052086353302002, 0.6056634187698364, 0.6324484944343567, 0.63958340883255, 0.6815946102142334, 0.7238074541091919, 0.6866214871406555, 0.6004131436347961, 0.608641505241394, 0.6247706413269043]
# BERTScore F1: [0.6422377228736877, 0.6249087452888489, 0.6089463829994202, 0.5705530643463135, 0.6005025506019592, 0.6556435227394104, 0.7400403022766113, 0.6424044966697693, 0.7064458131790161, 0.557918906211853, 0.5591279864311218, 0.632728099822998, 0.47163811326026917, 0.6320484280586243, 0.7197319865226746, 0.6173985600471497, 0.6652315258979797, 0.6194206476211548, 0.5985915660858154, 0.5118422508239746, 0.6268242001533508, 0.5485965013504028, 0.6145626306533813, 0.6327275037765503, 0.5787968039512634, 0.6163294911384583, 0.56148362159729, 0.6380969882011414, 0.6580113172531128, 0.6024879217147827, 0.6707992553710938, 0.6087296009063721, 0.5899264216423035, 0.6300114989280701, 0.6016553044319153, 0.6284347772598267, 0.5127969980239868, 0.6941413283348083, 0.548328161239624, 0.5768948197364807, 0.6301736831665039, 0.5936353802680969, 0.6057949662208557, 0.6518062353134155, 0.6050509810447693, 0.640362560749054, 0.6028693914413452, 0.6428743600845337, 0.703309178352356, 0.5993943214416504, 0.6224426627159119, 0.6068315505981445, 0.6227306127548218, 0.5739595293998718, 0.6497533321380615, 0.5473134517669678, 0.616526186466217, 0.5518161654472351, 0.6175181865692139, 0.6358364224433899, 0.6345372796058655, 0.6247783899307251, 0.6092085838317871, 0.6010317802429199, 0.6171015501022339, 0.5664551258087158, 0.6123383045196533, 0.690717875957489, 0.6632248163223267, 0.5192248821258545, 0.5762600302696228, 0.5860283374786377, 0.5800836086273193, 0.6425113081932068, 0.6269829273223877, 0.62447190284729, 0.6057152152061462, 0.55673748254776, 0.8588241338729858, 0.6182913184165955, 0.6041080951690674, 0.4966355562210083, 0.5301087498664856, 0.5675891637802124, 0.640325665473938, 0.6505910754203796, 0.6296852827072144, 0.6737397909164429, 0.5847646594047546, 0.5899431109428406, 0.6461072564125061, 0.6125807166099548, 0.6423131823539734, 0.6388860940933228, 0.671338677406311, 0.7272412776947021, 0.6339426636695862, 0.6340141892433167, 0.5994847416877747, 0.6091061234474182]

# %% [markdown]
# Bleu :BLEU score: 0.0044026828556608215
#
# ChRF : 7.6024692349810294
#
# Bertscore:0.6287417411804199
